# %% [markdown]
# Edits in branch would be to `__init__.py` (adding more properties), `obographs_DO.py` (adding to `APPEND_PROPS`) and `obographs_DO.py`(changing `try_write` to `False`). The branch also wouldn't have run because the last two lines are commented out...  Added `pathogen transmission process` to `__init__.py` and `obographs_DO.py`<br>

# %%
# %%bash
# python3 Test/scheduled-bots/scheduled_bots/ontology/obographs_DO.py ./Aprdoid.json

# %% [markdown]
# #### Test

# %%
# %%bash
# python3 Test/scheduled-bots/scheduled_bots/ontology/obographs_DO.py ./Aprdoid.json

# %% [markdown]
# #### Convert file to html
# Before Jenkin's run completion log.  Added new Statement `pathogen transmission process`. 1st test. After looking at the results... Of course more things would be updated in the first run vs the second run, as Jenkin's was not done with the task.

# %%
# %%bash
# python3 /home/rogertu/WikiData/scheduled-bots/scheduled_bots/logger/bot_log_parser.py /home/rogertu/WikiData/logs/'Disease Ontology-20190419_22:57.log'
# Out:
# /home/rogertu/WikiData/logs/Disease Ontology-20190419_22:57.log
# /home/rogertu/WikiData/WD_Test2/lib/python3.6/site-packages/pandas/core/generic.py:5079: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   object.__getattribute__(self, name)
# /home/rogertu/WikiData/WD_Test2/lib/python3.6/site-packages/pandas/core/generic.py:5080: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   return object.__setattr__(self, name, value)

# %% [markdown]
# After Jenkins run was complete log. 2nd test.

# %%
# %%bash
# python3 /home/rogertu/WikiData/scheduled-bots/scheduled_bots/logger/bot_log_parser.py /home/rogertu/WikiData/logs/'Disease Ontology-20190421_05:53.log'
# Out:
# /home/rogertu/WikiData/logs/Disease Ontology-20190421_05:53.log
# /home/rogertu/WikiData/WD_Test2/lib/python3.6/site-packages/pandas/core/generic.py:5079: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   object.__getattribute__(self, name)
# /home/rogertu/WikiData/WD_Test2/lib/python3.6/site-packages/pandas/core/generic.py:5080: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   return object.__setattr__(self, name, value)

# %% [markdown]
# #### I think the bot works as it is now...
# Scanning through the errors. I noticed two entries from NCBI_Taxon. Both entries were related to `pathogen transmission process`.  I fixed those two entries on WikiData so they have a corresponding QID now. The two entries are: <br><br>
# 5531				no qids found for: http://purl.obolibrary.org/obo/NCBITaxon_41820 <br>
# 24659				no qids found for: http://purl.obolibrary.org/obo/NCBITaxon_7180 <br>
# with corresponding QID's of Culicoides (Q2324817) and Haemagogus (Q5219942), respectively. <br>
#
# `has material basis in` also has a bunch of items that point to an NCBITaxon ID, but none of them showed up on the error log.

# %% [markdown]
# #### Updated the dev branch of github.
# Recloned the dev branch of github and reinstalled dependencies. Copied over my `local.py` file.

# %%
# %%bash
# python3 Test/scheduled-bots/scheduled_bots/ontology/obographs_DO.py ./Aprdoid.json
# Out:
# https://www.wikidata.org/w/api.php
# Successfully logged in as Torogertu
# Done running obographs_DO
# P699 not found in fastrun
# P2888 not found in fastrun
# P2892 not found in fastrun
# P486 not found in fastrun
# P1748 not found in fastrun
# P4229 not found in fastrun
# P1692 not found in fastrun
# P4317 not found in fastrun
# P1550 not found in fastrun
# P492 not found in fastrun
# fastrun failed at label: aliases, string: Edwards syndrome
# skipping 0 edges where the subject is a node that is being skipped
# P279 not found in fastrun
# P31 not found in fastrun
# loading: P1554
# P927 not found in fastrun
# None;None;None;no qids found for: http://purl.obolibrary.org/obo/UBERON_0004904;None
# None;None;None;multiple qids ({'Q2419844', 'Q1072'}) found for: http://purl.obolibrary.org/obo/UBERON_0000948;None
# None;None;None;multiple qids ({'Q1074', 'Q5259911'}) found for: http://purl.obolibrary.org/obo/UBERON_0002097;None
# loading: P685
# P1060 not found in fastrun
# ...

# %%
# %%bash
# python3 /home/rogertu/WikiData/scheduled-bots/scheduled_bots/logger/bot_log_parser.py /home/rogertu/WikiData/logs/'Disease Ontology-20190421_18:24.log'
# Out:
# /home/rogertu/WikiData/logs/Disease Ontology-20190421_18:24.log
# /home/rogertu/WikiData/WD_Test2/lib/python3.6/site-packages/pandas/core/generic.py:5079: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   object.__getattribute__(self, name)
# /home/rogertu/WikiData/WD_Test2/lib/python3.6/site-packages/pandas/core/generic.py:5080: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   return object.__setattr__(self, name, value)

# %% [markdown]
# Comparing `DO-20190421-05:53.html` and `DO-20190421-18:24.html`, only a difference of 2 less items in items skipped due to a warning.  This makes sense as I assigned the two NCBI taxons for `pathogen transmission process` on wikidata. Going to git merge my branch with my master, and do a pull request.
